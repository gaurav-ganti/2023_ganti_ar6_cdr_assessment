# %%
import pandas as pd

import seaborn as sns

from pathlib import Path

# %% [markdown]
# Step 1: Read in the necessary dataset.

# %%
df = pd.read_csv(
    Path(
        '../data/105_world.csv'
    ),
    index_col=[0,1]
)

# %%
sns.boxplot(
    y='cumulative_removals_2020_netzero',
    hue='category_pe_bio_netzero',
    data=df
)
# Out:
# <Axes: ylabel='cumulative_removals_2020_netzero'>

# %%
sns.boxplot(
    y='cumulative_removals_2020_netzero',
    hue='category_land_cover_netzero',
    data=df
)
# Out:
# <Axes: ylabel='cumulative_removals_2020_netzero'>
